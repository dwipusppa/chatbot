# %%
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from keras.models import load_model

# %%
# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("pertanian_paketingan.json").read()
intents = json.loads(data_file)

# %%
# preprocessing the json data
# tokenization
#nltk.download('punkt')
#nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('texts.pkl','wb')) 
pickle.dump(classes,open('labels.pkl','wb'))
# Out:
# 56 documents
# 29 classes ['TaniBot', 'berapa_kali_panen', 'ciri_hama_tikus', 'ciri_hama_wereng', 'goodbye', 'greeting', 'harga_padi', 'jenis_bibit', 'jenis_pupuk', 'jenis_tanah', 'kendala_petani', 'lama_panen', 'lama_panen_dari_hamil', 'memantau_padi', 'mengolah_padi_beras', 'pembajakan_sawah', 'pemisahan_padi', 'penanggulangan_hama', 'penanggulangan_hama_tikus', 'penanggulangan_hama_wereng', 'penyebab_gagal_panen', 'perairan_sawah', 'perawatan_sawah', 'persentasi_hasil_panen', 'proses_menanam_padi', 'sistem_pertanian_paketingan', 'sumber_perairan_sawah', 'target_pasar', 'terimakasih']
# 104 unique lemmatized words ['1', 'afternoon', 'agar', 'alami', 'apa', 'bagaimana', 'bai', 'banyak', 'berapa', 'beras', 'bibit', 'bisa', 'bro', 'bye', 'byee', 'cara', 'ciri-ciri', 'dadah', 'dah', 'dalam', 'dari', 'desa', 'di', 'digunakan', 'ditanam', 'gagal', 'good', 'hai', 'hallo', 'halo', 'hama', 'hamil', 'harga', 'hasil', 'hei', 'hi', 'hy', 'itu', 'jenis', 'jual', 'jumpa', 'kali', 'kasih', 'kawan', 'ke', 'kendala', 'kondisi', 'lahan', 'lama', 'makasih', 'malam', 'memantau', 'menanam', 'mengolah', 'menjadi', 'morning', 'padi', 'pagi', 'paketingan', 'panen', 'pasar', 'pembajakan', 'pemisahan', 'penanggulangan', 'penggunaan', 'penyebab', 'perairan', 'perawatan', 'persawahan', 'persentase', 'pertanian', 'petani', 'pohon', 'prose', 'pupuk', 'saja', 'sampai', 'sawah', 'see', 'selamat', 'sering', 'si', 'siang', 'siapa', 'sistem', 'sore', 'sumber', 'tahun', 'tanah', 'tanaman', 'tanibot', 'target', 'terhindar', 'terima', 'terserang', 'thank', 'thanks', 'tikus', 'tinggal', 'untuk', 'waktu', 'wereng', 'yang', 'you']

# %%
# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features and converting it into numpy arrays
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %%
# Create NN model to predict the responses
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               13440
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 29)                1885
#
# =================================================================
# Total params: 23,581
# Trainable params: 23,581
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
# train model
history = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 12s 41ms/step - loss: 3.4109 - accuracy: 0.0357
# Epoch 2/200
# 12/12 [==============================] - 0s 4ms/step - loss: 3.2667 - accuracy: 0.2857
# Epoch 3/200
# 12/12 [==============================] - 0s 4ms/step - loss: 3.1417 - accuracy: 0.2679
# Epoch 4/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.9849 - accuracy: 0.2679
# Epoch 5/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.8476 - accuracy: 0.2679
# Epoch 6/200
# 12/12 [==============================] - 0s 5ms/step - loss: 2.6956 - accuracy: 0.2679
# Epoch 7/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5443 - accuracy: 0.2679
# Epoch 8/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5388 - accuracy: 0.2679
# Epoch 9/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.4671 - accuracy: 0.2857
# Epoch 10/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2812 - accuracy: 0.3393
# Epoch 11/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2342 - accuracy: 0.3393
# Epoch 12/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0248 - accuracy: 0.3393
# Epoch 13/200
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1239 - accuracy: 0.3571
# Epoch 14/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9297 - accuracy: 0.2857
# Epoch 15/200
# 12/12 [==============================] - 0s 5ms/step - loss: 1.7317 - accuracy: 0.4464
# Epoch 16/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7745 - accuracy: 0.5000
# Epoch 17/200
# 12/12 [==============================] - 0s 5ms/step - loss: 1.5664 - accuracy: 0.4821
# Epoch 18/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6822 - accuracy: 0.4464
# Epoch 19/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6626 - accuracy: 0.4464
# Epoch 20/200
# 12/12 [==============================] - 0s 5ms/step - loss: 1.3529 - accuracy: 0.5714
# Epoch 21/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4701 - accuracy: 0.4643
# Epoch 22/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3043 - accuracy: 0.6429
# Epoch 23/200
# 12/12 [==============================] - 0s 6ms/step - loss: 1.3953 - accuracy: 0.5536
# Epoch 24/200
# 12/12 [==============================] - 0s 5ms/step - loss: 1.4820 - accuracy: 0.5893
# Epoch 25/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0822 - accuracy: 0.6250
# Epoch 26/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2408 - accuracy: 0.6071
# Epoch 27/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1716 - accuracy: 0.6250
# Epoch 28/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1189 - accuracy: 0.6786
# Epoch 29/200
# 12/12 [==============================] - 0s 5ms/step - loss: 1.2873 - accuracy: 0.5536
# Epoch 30/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0987 - accuracy: 0.6429
# Epoch 31/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0376 - accuracy: 0.7500
# Epoch 32/200
# 12/12 [==============================] - 0s 5ms/step - loss: 1.1016 - accuracy: 0.7143
# Epoch 33/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7551 - accuracy: 0.7321
# Epoch 34/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9272 - accuracy: 0.7143
# Epoch 35/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8950 - accuracy: 0.7500
# Epoch 36/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7922 - accuracy: 0.7679
# Epoch 37/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7566 - accuracy: 0.7500
# Epoch 38/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.9394 - accuracy: 0.6786
# Epoch 39/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7270 - accuracy: 0.7857
# Epoch 40/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7392 - accuracy: 0.7321
# Epoch 41/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7529 - accuracy: 0.7321
# Epoch 42/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4844 - accuracy: 0.8036
# Epoch 43/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7412 - accuracy: 0.7500
# Epoch 44/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6162 - accuracy: 0.8393
# Epoch 45/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7118 - accuracy: 0.8036
# Epoch 46/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6353 - accuracy: 0.7679
# Epoch 47/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6262 - accuracy: 0.8393
# Epoch 48/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5847 - accuracy: 0.8214
# Epoch 49/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4866 - accuracy: 0.8214
# Epoch 50/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4838 - accuracy: 0.8571
# Epoch 51/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3851 - accuracy: 0.8929
# Epoch 52/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4553 - accuracy: 0.8750
# Epoch 53/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5071 - accuracy: 0.8571
# Epoch 54/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4964 - accuracy: 0.8393
# Epoch 55/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3401 - accuracy: 0.8929
# Epoch 56/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5700 - accuracy: 0.8393
# Epoch 57/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4811 - accuracy: 0.8214
# Epoch 58/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4182 - accuracy: 0.8750
# Epoch 59/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4779 - accuracy: 0.8571
# Epoch 60/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5616 - accuracy: 0.8571
# Epoch 61/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4594 - accuracy: 0.9107
# Epoch 62/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4667 - accuracy: 0.8571
# Epoch 63/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4771 - accuracy: 0.8571
# Epoch 64/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3379 - accuracy: 0.9107
# Epoch 65/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4999 - accuracy: 0.8214
# Epoch 66/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4307 - accuracy: 0.8929
# Epoch 67/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3557 - accuracy: 0.8929
# Epoch 68/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3199 - accuracy: 0.8929
# Epoch 69/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2807 - accuracy: 0.9286
# Epoch 70/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4179 - accuracy: 0.8393
# Epoch 71/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3686 - accuracy: 0.8929
# Epoch 72/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4125 - accuracy: 0.8750
# Epoch 73/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3437 - accuracy: 0.8929
# Epoch 74/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3359 - accuracy: 0.8929
# Epoch 75/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2895 - accuracy: 0.9286
# Epoch 76/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2928 - accuracy: 0.9286
# Epoch 77/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3656 - accuracy: 0.8214
# Epoch 78/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4217 - accuracy: 0.8750
# Epoch 79/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2914 - accuracy: 0.9286
# Epoch 80/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1943 - accuracy: 0.9643
# Epoch 81/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4553 - accuracy: 0.8750
# Epoch 82/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3044 - accuracy: 0.9464
# Epoch 83/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1423 - accuracy: 0.9643
# Epoch 84/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2240 - accuracy: 0.9286
# Epoch 85/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4038 - accuracy: 0.8750
# Epoch 86/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3439 - accuracy: 0.8750
# Epoch 87/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3494 - accuracy: 0.8929
# Epoch 88/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2113 - accuracy: 0.9286
# Epoch 89/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2813 - accuracy: 0.9107
# Epoch 90/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2108 - accuracy: 0.9464
# Epoch 91/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1732 - accuracy: 0.9286
# Epoch 92/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1453 - accuracy: 0.9464
# Epoch 93/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2189 - accuracy: 0.9107
# Epoch 94/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2703 - accuracy: 0.9107
# Epoch 95/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3755 - accuracy: 0.8750
# Epoch 96/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2201 - accuracy: 0.9464
# Epoch 97/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3243 - accuracy: 0.9286
# Epoch 98/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3369 - accuracy: 0.8929
# Epoch 99/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1126 - accuracy: 0.9821
# Epoch 100/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2614 - accuracy: 0.9286
# Epoch 101/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2906 - accuracy: 0.8929
# Epoch 102/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1424 - accuracy: 0.9643
# Epoch 103/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1408 - accuracy: 0.9643
# Epoch 104/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1639 - accuracy: 0.9643
# Epoch 105/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2533 - accuracy: 0.8929
# Epoch 106/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2150 - accuracy: 0.9286
# Epoch 107/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1952 - accuracy: 0.9643
# Epoch 108/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3048 - accuracy: 0.9107
# Epoch 109/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1330 - accuracy: 0.9643
# Epoch 110/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1041 - accuracy: 0.9821
# Epoch 111/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2019 - accuracy: 0.9107
# Epoch 112/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2181 - accuracy: 0.9464
# Epoch 113/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2758 - accuracy: 0.8929
# Epoch 114/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3564 - accuracy: 0.8750
# Epoch 115/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2230 - accuracy: 0.9286
# Epoch 116/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2378 - accuracy: 0.9107
# Epoch 117/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1837 - accuracy: 0.9643
# Epoch 118/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2982 - accuracy: 0.8929
# Epoch 119/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2116 - accuracy: 0.9286
# Epoch 120/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2227 - accuracy: 0.9286
# Epoch 121/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2569 - accuracy: 0.9107
# Epoch 122/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9643
# Epoch 123/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1436 - accuracy: 0.9643
# Epoch 124/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1871 - accuracy: 0.9286
# Epoch 125/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1547 - accuracy: 0.9464
# Epoch 126/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1241 - accuracy: 0.9643
# Epoch 127/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2811 - accuracy: 0.8929
# Epoch 128/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1286 - accuracy: 0.9821
# Epoch 129/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2345 - accuracy: 0.9107
# Epoch 130/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1346 - accuracy: 0.9821
# Epoch 131/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1004 - accuracy: 1.0000
# Epoch 132/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3219 - accuracy: 0.9107
# Epoch 133/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2586 - accuracy: 0.8571
# Epoch 134/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2473 - accuracy: 0.9286
# Epoch 135/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2776 - accuracy: 0.9107
# Epoch 136/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1349 - accuracy: 0.9821
# Epoch 137/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2090 - accuracy: 0.9464
# Epoch 138/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3085 - accuracy: 0.9107
# Epoch 139/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9821
# Epoch 140/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1279 - accuracy: 1.0000
# Epoch 141/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1081 - accuracy: 0.9821
# Epoch 142/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1991 - accuracy: 0.9464
# Epoch 143/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1341 - accuracy: 0.9464
# Epoch 144/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1636 - accuracy: 0.9643
# Epoch 145/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2228 - accuracy: 0.9286
# Epoch 146/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2280 - accuracy: 0.9464
# Epoch 147/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1993 - accuracy: 0.9107
# Epoch 148/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1548 - accuracy: 0.9464
# Epoch 149/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1886 - accuracy: 0.9286
# Epoch 150/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2688 - accuracy: 0.8750
# Epoch 151/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1326 - accuracy: 0.9643
# Epoch 152/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.9643
# Epoch 153/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2510 - accuracy: 0.9643
# Epoch 154/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1901 - accuracy: 0.9286
# Epoch 155/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1671 - accuracy: 0.9464
# Epoch 156/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1533 - accuracy: 0.9643
# Epoch 157/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1141 - accuracy: 0.9643
# Epoch 158/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0878 - accuracy: 0.9821
# Epoch 159/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 1.0000
# Epoch 160/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1258 - accuracy: 0.9643
# Epoch 161/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1564 - accuracy: 0.9286
# Epoch 162/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0944 - accuracy: 0.9821
# Epoch 163/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2919 - accuracy: 0.9107
# Epoch 164/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2218 - accuracy: 0.9107
# Epoch 165/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0955 - accuracy: 0.9821
# Epoch 166/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1004 - accuracy: 0.9821
# Epoch 167/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1664 - accuracy: 0.9464
# Epoch 168/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0700 - accuracy: 1.0000
# Epoch 169/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1998 - accuracy: 0.9643
# Epoch 170/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1639 - accuracy: 0.9643
# Epoch 171/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3726 - accuracy: 0.8571
# Epoch 172/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1236 - accuracy: 0.9821
# Epoch 173/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0878 - accuracy: 0.9643
# Epoch 174/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0864 - accuracy: 0.9643
# Epoch 175/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2862 - accuracy: 0.9107
# Epoch 176/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1512 - accuracy: 0.9107
# Epoch 177/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0791 - accuracy: 1.0000
# Epoch 178/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2087 - accuracy: 0.9286
# Epoch 179/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1268 - accuracy: 0.9643
# Epoch 180/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1245 - accuracy: 0.9643
# Epoch 181/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1320 - accuracy: 0.9643
# Epoch 182/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1530 - accuracy: 0.9643
# Epoch 183/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1615 - accuracy: 0.9286
# Epoch 184/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0817 - accuracy: 0.9821
# Epoch 185/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1332 - accuracy: 0.9464
# Epoch 186/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2597 - accuracy: 0.9464
# Epoch 187/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2479 - accuracy: 0.9464
# Epoch 188/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0898 - accuracy: 0.9643
# Epoch 189/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1280 - accuracy: 0.9107
# Epoch 190/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.9821
# Epoch 191/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2345 - accuracy: 0.9107
# Epoch 192/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1576 - accuracy: 0.9286
# Epoch 193/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0660 - accuracy: 0.9821
# Epoch 194/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.9464
# Epoch 195/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1026 - accuracy: 0.9821
# Epoch 196/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1066 - accuracy: 0.9643
# Epoch 197/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2304 - accuracy: 0.9107
# Epoch 198/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1962 - accuracy: 0.9286
# Epoch 199/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1833 - accuracy: 0.9107
# Epoch 200/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1460 - accuracy: 0.9821

# %%
model.save('models.h5', history)
